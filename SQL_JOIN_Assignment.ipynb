# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmughamkarthik-eng/SQL_Assignment/blob/main/SQL_JOIN_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CREATE TABLE products (
    product_id INT PRIMARY KEY,
    product_name VARCHAR(50),
    category VARCHAR(50),
    price INT
);

INSERT INTO products VALUES
(1, 'Laptop', 'Electronics', 70000),
(2, 'Mouse', 'Electronics', 500),
(3, 'Keyboard', 'Electronics', 1500),
(4, 'Office Chair', 'Furniture', 8000),
(5, 'Desk', 'Furniture', 12000);


CREATE TABLE inventory (
    inventory_id INT PRIMARY KEY,
    product_id INT,
    warehouse VARCHAR(50),
    stock_quantity INT
);

INSERT INTO inventory VALUES
(101, 1, 'Warehouse_A', 50),
(102, 1, 'Warehouse_B', 30),
(103, 2, 'Warehouse_A', 200),
(104, 3, 'Warehouse_A', 150),
(105, 6, 'Warehouse_B', 40);

# %% [markdown]
# #Inner Join

# %%
SELECT
p.product_name,
i.warehouse,
i.stock_quantity
FROM products p
INNER JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME WAREHOUSE     STOCK_QUANTITY
#       ------------ ------------- --------------
#       Laptop       Warehouse_A   50
#       Laptop       Warehouse_B   30
#       Mouse        Warehouse_A   200
#       Keyboard     Warehouse_A   150
#
#       Elapsed: 00:00:00.001
#       4 rows selected.

# %% [markdown]
# #LEFT JOIN

# %%
SELECT
p.product_name,
i.warehouse,
i.stock_quantity
FROM products p
LEFT JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE     STOCK_QUANTITY
#       -------------- ------------- --------------
#       Laptop         Warehouse_A   50
#       Laptop         Warehouse_B   30
#       Mouse          Warehouse_A   200
#       Keyboard       Warehouse_A   150
#       Office Chair
#       Desk
#
#       Elapsed: 00:00:00.001
#       6 rows selected.

# %% [markdown]
# #RIGHT JOIN

# %%
SELECT
p.product_name,
i.warehouse,
i.stock_quantity
FROM products p
RIGHT JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME WAREHOUSE     STOCK_QUANTITY
#       ------------ ------------- --------------
#       Laptop       Warehouse_A   50
#       Laptop       Warehouse_B   30
#       Mouse        Warehouse_A   200
#       Keyboard     Warehouse_A   150
#                   Warehouse_B   40
#
#       Elapsed: 00:00:00.002
#       5 rows selected.

# %% [markdown]
# #FULL OUTER JOIN

# %%
SELECT
p.product_name,
i.warehouse,
i.stock_quantity
FROM products p
FULL OUTER JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE     STOCK_QUANTITY
#       -------------- ------------- --------------
#       Laptop         Warehouse_A   50
#       Laptop         Warehouse_B   30
#       Mouse          Warehouse_A   200
#       Keyboard       Warehouse_A   150
#                     Warehouse_B   40
#       Office Chair
#       Desk
#
#       Elapsed: 00:00:00.002
#       7 rows selected.

# %% [markdown]
# #CROSS JOIN

# %%
SELECT
p.product_name,
i.warehouse
FROM products p
CROSS JOIN inventory i;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE
#       -------------- -------------
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_B
#       Mouse          Warehouse_B
#       Keyboard       Warehouse_B
#       Office Chair   Warehouse_B
#       Desk           Warehouse_B
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_B
#       Mouse          Warehouse_B
#       Keyboard       Warehouse_B
#       Office Chair   Warehouse_B
#       Desk           Warehouse_B
#
#       Elapsed: 00:00:00.002
#       25 rows selected.

# %% [markdown]
# ###-- ================================
# ###-- Inventory JOIN Practice Questions & Answers
# ###-- Tables Used:
# ###-- products(product_id, product_name, category, price)
# ###-- inventory(inventory_id, product_id, warehouse, stock_quantity)
# ###-- ================================

# %%
# -- 1. Show all products with their warehouse and stock quantity.
SELECT p.product_name, i.warehouse, i.stock_quantity
FROM products p
JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME WAREHOUSE     STOCK_QUANTITY
#       ------------ ------------- --------------
#       Laptop       Warehouse_A   50
#       Laptop       Warehouse_B   30
#       Mouse        Warehouse_A   200
#       Keyboard     Warehouse_A   150
#
#       Elapsed: 00:00:00.006
#       4 rows selected.

# %%
# -- 2. Show all products even if they do not exist in inventory.
SELECT p.product_name, i.warehouse, i.stock_quantity
FROM products p
LEFT JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE     STOCK_QUANTITY
#       -------------- ------------- --------------
#       Laptop         Warehouse_A   50
#       Laptop         Warehouse_B   30
#       Mouse          Warehouse_A   200
#       Keyboard       Warehouse_A   150
#       Office Chair
#       Desk
#
#       Elapsed: 00:00:00.005
#       6 rows selected.

# %%
# -- 3. Show all inventory records even if product details are missing.
SELECT p.product_name, i.warehouse, i.stock_quantity
FROM products p
RIGHT JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME WAREHOUSE     STOCK_QUANTITY
#       ------------ ------------- --------------
#       Laptop       Warehouse_A   50
#       Laptop       Warehouse_B   30
#       Mouse        Warehouse_A   200
#       Keyboard     Warehouse_A   150
#                   Warehouse_B   40
#
#       Elapsed: 00:00:00.006
#       5 rows selected.

# %%
# -- 4. Show all records from both tables (matched and unmatched).
SELECT p.product_name, i.warehouse, i.stock_quantity
FROM products p
FULL OUTER JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE     STOCK_QUANTITY
#       -------------- ------------- --------------
#       Laptop         Warehouse_A   50
#       Laptop         Warehouse_B   30
#       Mouse          Warehouse_A   200
#       Keyboard       Warehouse_A   150
#                     Warehouse_B   40
#       Office Chair
#       Desk
#
#       Elapsed: 00:00:00.002
#       7 rows selected.

# %%
# -- 5. Find products available in Warehouse_A.
SELECT p.product_name, i.stock_quantity
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
WHERE i.warehouse = 'Warehouse_A';

# %% [markdown]
#       PRODUCT_NAME STOCK_QUANTITY
#       ------------ --------------
#       Laptop       50
#       Mouse        200
#       Keyboard     150
#
#       Elapsed: 00:00:00.097
#       3 rows selected.

# %%
# -- 6. Find products available in Warehouse_B.
SELECT p.product_name, i.stock_quantity
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
WHERE i.warehouse = 'Warehouse_B';

# %% [markdown]
#       PRODUCT_NAME STOCK_QUANTITY
#       ------------ --------------
#       Laptop       30
#
#       Elapsed: 00:00:00.002
#       1 rows selected.

# %%
# -- 7. Find products with stock greater than 100.
SELECT p.product_name, i.stock_quantity
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
WHERE i.stock_quantity > 100;

# %% [markdown]
#       PRODUCT_NAME STOCK_QUANTITY
#       ------------ --------------
#       Mouse        200
#       Keyboard     150
#
#       Elapsed: 00:00:00.006
#       2 rows selected.

# %%
# -- 8. Find total stock for each product.
SELECT p.product_name, SUM(i.stock_quantity) AS total_stock
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name;

# %% [markdown]
#       PRODUCT_NAME TOTAL_STOCK
#       ------------ -----------
#       Laptop       80
#       Mouse        200
#       Keyboard     150
#
#       Elapsed: 00:00:00.007
#       3 rows selected.

# %%
# -- 9. Find the total inventory value for each product.
SELECT p.product_name,
SUM(p.price * i.stock_quantity) AS inventory_value
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name;

# %% [markdown]
#       PRODUCT_NAME INVENTORY_VALUE
#       ------------ ---------------
#       Laptop       5600000
#       Mouse        100000
#       Keyboard     225000
#
#       Elapsed: 00:00:00.012
#       3 rows selected.

# %%
# -- 10. Find products that do not exist in inventory.
SELECT p.product_name
FROM products p
LEFT JOIN inventory i
ON p.product_id = i.product_id
WHERE i.product_id IS NULL;

# %% [markdown]
#       PRODUCT_NAME
#       --------------
#       Office Chair
#       Desk
#
#       Elapsed: 00:00:00.005
#       2 rows selected.

# %%
# -- 11. Find inventory records with no matching product.
SELECT i.inventory_id, i.product_id
FROM inventory i
LEFT JOIN products p
ON p.product_id = i.product_id
WHERE p.product_id IS NULL;

# %% [markdown]
#       INVENTORY_ID PRODUCT_ID
#       ------------ ----------
#       105          6
#
#       Elapsed: 00:00:00.005
#       1 rows selected.

# %%
# -- 12. Find product names and categories stored in Warehouse_A.
SELECT p.product_name, p.category, i.warehouse
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
WHERE i.warehouse = 'Warehouse_A';

# %% [markdown]
#       PRODUCT_NAME CATEGORY      WAREHOUSE
#       ------------ ------------- -------------
#       Laptop       Electronics   Warehouse_A
#       Mouse        Electronics   Warehouse_A
#       Keyboard     Electronics   Warehouse_A
#
#       Elapsed: 00:00:00.006
#       3 rows selected.

# %%
# -- 13. Find the number of warehouses storing each product.
SELECT p.product_name, COUNT(i.warehouse) AS warehouse_count
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name;

# %% [markdown]
#       PRODUCT_NAME WAREHOUSE_COUNT
#       ------------ ---------------
#       Laptop       2
#       Mouse        1
#       Keyboard     1
#
#       Elapsed: 00:00:00.094
#       3 rows selected.

# %%
# -- 14. Find the highest stock quantity for each product.
SELECT p.product_name, MAX(i.stock_quantity) AS highest_stock
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name;

# %% [markdown]
#       PRODUCT_NAME HIGHEST_STOCK
#       ------------ -------------
#       Laptop       50
#       Mouse        200
#       Keyboard     150
#
#       Elapsed: 00:00:00.007
#       3 rows selected.

# %%
# -- 15. Find the lowest stock quantity for each product.
SELECT p.product_name, MIN(i.stock_quantity) AS lowest_stock
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name;

# %% [markdown]
#       PRODUCT_NAME LOWEST_STOCK
#       ------------ ------------
#       Laptop       30
#       Mouse        200
#       Keyboard     150
#
#       Elapsed: 00:00:00.008
#       3 rows selected.

# %%
# -- 16. Find products and their price along with stock quantity.
SELECT p.product_name, p.price, i.stock_quantity
FROM products p
JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME PRICE STOCK_QUANTITY
#       ------------ ----- --------------
#       Laptop       70000 50
#       Laptop       70000 30
#       Mouse        500   200
#       Keyboard     1500  150
#
#       Elapsed: 00:00:00.005
#       4 rows selected.

# %%
# -- 17. Find total stock available in each warehouse.
SELECT i.warehouse, SUM(i.stock_quantity) AS total_stock
FROM inventory i
GROUP BY i.warehouse;

# %% [markdown]
#       WAREHOUSE     TOTAL_STOCK
#       ------------- -----------
#       Warehouse_A   400
#       Warehouse_B   70
#
#       Elapsed: 00:00:00.003
#       2 rows selected.

# %%
# -- 18. Find products whose total stock is greater than 200.
SELECT p.product_name, SUM(i.stock_quantity) AS total_stock
FROM products p
JOIN inventory i
ON p.product_id = i.product_id
GROUP BY p.product_name
HAVING SUM(i.stock_quantity) > 200;

# %% [markdown]
# 0 rows selected.

# %%
# -- 19. Find all combinations of products and warehouses.
SELECT p.product_name, i.warehouse
FROM products p
CROSS JOIN inventory i;

# %% [markdown]
#       PRODUCT_NAME   WAREHOUSE
#       -------------- -------------
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_B
#       Mouse          Warehouse_B
#       Keyboard       Warehouse_B
#       Office Chair   Warehouse_B
#       Desk           Warehouse_B
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_A
#       Mouse          Warehouse_A
#       Keyboard       Warehouse_A
#       Office Chair   Warehouse_A
#       Desk           Warehouse_A
#       Laptop         Warehouse_B
#       Mouse          Warehouse_B
#       Keyboard       Warehouse_B
#       Office Chair   Warehouse_B
#       Desk           Warehouse_B
#
#       Elapsed: 00:00:00.005
#       25 rows selected.

# %%
# -- 20. Find products that exist in both tables (semi join concept).
SELECT DISTINCT p.product_name
FROM products p
JOIN inventory i
ON p.product_id = i.product_id;

# %% [markdown]
#       PRODUCT_NAME
#       ------------
#       Laptop
#       Mouse
#       Keyboard
#
#       Elapsed: 00:00:00.006
#       3 rows selected.
